# %%
import logging

logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s | %(message)s")

from warnings import filterwarnings

filterwarnings("ignore")

import pandas as pd
import numpy as np

from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc("font", **{"size": 22})

from investment_lab.option_selection import select_options
from investment_lab.metrics.volatility import rolling_realized_volatility
from investment_lab.metrics.util import levels_to_returns
from investment_lab.data.option_db import OptionLoader, SPYOptionLoader, extract_spot_from_options
from investment_lab.data.rates_db import USRatesLoader
from investment_lab.pricing.black_scholes import black_scholes_price, black_scholes_greeks
#from investment_lab.pricing.implied_volatility import implied_volatility_vectorized
from investment_lab.rates import compute_forward
from investment_lab.metrics.distance import mse, sse
#from investment_lab.surface.sabr import SABRSmoother
from investment_lab.surface.ssvi import SSVISmoother

# %%
print("Test 2")
# Out:
# Test 2

# %%
df_options = OptionLoader.load_data(
    datetime(2022, 1, 4),
    datetime(2022, 1, 4),
    process_kwargs={"ticker": "AAPL"},
)
df_options.head()
# Out:
# 2026-03-22 17:28:48,748 | INFO | Reading between 2022-01-04 00:00:00 2022-01-04 00:00:00 from C:\Users\Dell\Desktop\Dauphine\projet_trading_vol\data\optiondb_2016_2023.parquet with None
# 2026-03-22 17:28:57,450 | INFO | Processing with {'ticker': 'AAPL'}
# 2026-03-22 17:28:57,452 | INFO | Potentially add extra field with None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_options = OptionLoader.load_data(
#       2     datetime(2022, 1, 4),
#       3     datetime(2022, 1, 4),
#       4     process_kwargs={"ticker": "AAPL"},
#       5 )
#       6 df_options.head()
#
# File c:\Users\Dell\Desktop\Dauphine\projet_trading_vol\investment_lab\data\data_loader.py:53, in DataLoader.load_data(cls, start_date, end_date, load_kwargs, process_kwargs, extra_fields_kwargs)
#      50 logging.info("Processing with %s", process_kwargs)
#      51 logging.info("Potentially add extra field with %s", extra_fields_kwargs)
#      52 df_processed = cls._add_extra_fields(
# ---> 53     cls._process_loaded_data(df, **(process_kwargs or {})),
#      54     **(extra_fields_kwargs or {}),
#      55 )
#      56 return df_processed[df_processed["date"].between(start_date, end_date)]
#
# File c:\Users\Dell\Desktop\Dauphine\projet_trading_vol\investment_lab\data\option_db.py:33, in OptionLoader._process_loaded_data(cls, df, ticker, **kwargs)
#      31 df = df[df["ticker"].isin(ticker)]
#      32 df["volume"] = df["volume"].fillna(0)
# ---> 33 return cls._compute_final_payoff(df)
#
# File c:\Users\Dell\Desktop\Dauphine\projet_trading_vol\investment_lab\data\option_db.py:51, in OptionLoader._compute_final_payoff(df_option)
#      48 put_payoff = (df_option["strike"] - df_option["spot"]).clip(lower=0)
#      50 for c in ("mid", "bid", "ask"):
# ---> 51     df_option[c] = np.where(
#      52         expiring_calls_filter,
#      53         call_payoff,
#      54         np.where(expiring_puts_filter, put_payoff, df_option[c]),
#      55     )
#      56 return df_option
#
# NameError: name 'np' is not defined

# %%
print("LOADED option_db.py")
# Out:
# LOADED option_db.py

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
print(sys.executable)
# Out:
# Running cells with '.venv (Python 3.11.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Dell/Desktop/Dauphine/projet_trading_vol/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
